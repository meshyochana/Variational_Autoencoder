# %%
# %matplotlib inline
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.optim import Adam
from sklearn.manifold import TSNE
from matplotlib.colors import ListedColormap

import matplotlib.pyplot as plt
import numpy as np

from config_mnist import device, BATCH_SIZE, EPOCHS, latent_dim
import vae_mnist as vae_mnist

# %%
print(latent_dim)
# Out:
# 5

# %% [markdown]
# # Train the model

# %%
trained_model = vae_mnist.VariationalAutoencoder().to(device)

losses = []
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('./data', train=True, download=True,
                   transform=transforms.ToTensor()),
    batch_size=128, shuffle=True)

for epoch in range(EPOCHS):  
    loss = vae_mnist.train(trained_model, train_loader)
    losses.append(loss)
# Out:
# 5

# %%
print(trained_model)
# Out:
# VariationalAutoencoder(
#   (encoder): Sequential(
#     (0): Linear(in_features=784, out_features=400, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=400, out_features=40, bias=True)
#   )
#   (fc_mu): Linear(in_features=40, out_features=5, bias=True)
#   (fc_log_var): Linear(in_features=40, out_features=5, bias=True)
#   (decoder): Sequential(
#     (0): Linear(in_features=5, out_features=400, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=400, out_features=784, bias=True)
#     (3): Sigmoid()
#   )
# )

# %%
torch.save(trained_model.state_dict(), "pth/vae_model_ldim_5.pth")

# %%
# Reinitialize the model architecture
loaded_model = vae_mnist.VariationalAutoencoder(latent_dim).to(device)  # Ensure the architecture matches the saved model
loaded_model.load_state_dict(torch.load("pth/vae_model_ldim_5.pth"))
loaded_model.eval()  # Set the model to evaluation mode
trained_model = loaded_model
# Out:
# C:\Users\meshy\AppData\Local\Temp\ipykernel_108128\179000662.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_model.load_state_dict(torch.load("pth/vae_model_ldim_2.pth"))

# %% [markdown]
# # Plot the model loss across epochs

# %%
vae_mnist.plot_loss(losses)

# %% [markdown]
# # Test the model (qualitatively)

# %%
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('./data', train=False, transform=transforms.ToTensor()),
    batch_size=BATCH_SIZE, shuffle=True)

vae_mnist.visualize_reconstructions(trained_model, test_loader)
# Out:
# latent dim =  5
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Generate new digits

# %%
plot_samples = 5
num_samples = 100  # Number of digits you want to generate
z, generated_digits = vae_mnist.generate_new_digits(trained_model, num_samples)
# Out:
# torch.Size([100, 5])

# %%
vae_mnist.plot_digits_and_latents(z, generated_digits, plot_samples)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Project the latent space into 2d space (using t-NSE alg)

# %%
mnist = datasets.MNIST(root='./data', train=False, download=True, transform=transforms.ToTensor())
loader = torch.utils.data.DataLoader(mnist, batch_size=1000, shuffle=True)

# Get a batch of data
data, labels = next(iter(loader))
data = data.to(device)
labels = labels.numpy()  

# Use the encoder to get the latent variables
trained_model.eval()
with torch.no_grad():
    mu, _ = trained_model.encode(data)
    mu = mu.cpu().numpy()  # Convert to NumPy array for visualization

# %%
new_labels = np.concatenate([labels, [11 for i in range(plot_samples)]])#

# %%
tsne = TSNE(n_components=2, random_state=0)
full_latent_vectors = np.vstack([mu, z[0:5]])
latent_tsne = tsne.fit_transform(full_latent_vectors)  # Use latent space representations for visualization

# %%
plt.close('all')
fig, ax = plt.subplots(1,1, figsize=(10, 8))

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd',
          '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#000000']
custom_cmap = ListedColormap(colors)

scatter = ax.scatter(latent_tsne[:, 0], latent_tsne[:, 1], c=new_labels, cmap=custom_cmap, alpha=0.6)
ax.scatter(latent_tsne[-plot_samples:, 0], latent_tsne[-plot_samples:, 1], c='k', s=100, alpha=0.6)

fig.colorbar(scatter, ticks=range(11), label='Digit Class')
ax.set_title('2D t-SNE of Latent Space')
ax.set_xlabel('t-SNE Feature 1')
ax.set_ylabel('t-SNE Feature 2')
ax.grid(True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
